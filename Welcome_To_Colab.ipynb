# %% [markdown]
# <a href="https://colab.research.google.com/github/harshinis24mss066-ctrl/AIML-AND-CYBER-SECURITY-VAC/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b408bbea-449a-4901-b31a-7a3fad9cb09c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b408bbea-449a-4901-b31a-7a3fad9cb09c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os
if not os.path.exists('./dataset'):
    os.makedirs('./dataset')

with zipfile.ZipFile('archive (1).zip','r') as zip_ref:
  zip_ref.extractall('./dataset')


dp=pd.read_csv('./dataset/creditcard.csv')
dp.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
x = dp.drop("Class",axis=1)
y = dp["Class"]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train_scaled, y_train)

print("MODEL TRAINED SUCCESSFULLY!")
# Out:
# MODEL TRAINED SUCCESSFULLY!

# %%
import numpy as np
def Predict_fraud(input_list):
  scaled=scaler.transform(np.array(input_list).reshape(1, -1))
  pred=model.predict(scaled)[0]
  return "FRAUD" if pred == 1 else "NOT FRAUD"
  print("\n Enter transcation details to predict")

# %%
sample =[]
for col in x.columns:
   value = float(input(f"Enter the value for column {col}: "))
   sample.append(value)


result = Predict_fraud(sample)
print(f"\nPrediction: {result}")
# Out:
# Enter the value for column Time: 0.5
# Enter the value for column V1: 8.6
# Enter the value for column V2: 7.8
# Enter the value for column V3: 5.6
# Enter the value for column V4: 5.4
# Enter the value for column V5: 3.4
# Enter the value for column V6: 8.8
# Enter the value for column V7: 2.3
# Enter the value for column V8: 4.5
# Enter the value for column V9: 6.7
# Enter the value for column V10: 8.1
# Enter the value for column V11: 5.6
# Enter the value for column V12: 8.5
# Enter the value for column V13: 6.8
# Enter the value for column V14: 34.5
# Enter the value for column V15: 67.8
# Enter the value for column V16: 8.9
# Enter the value for column V17: 3.45
# Enter the value for column V18: 6.7
# Enter the value for column V19: 4.5
# Enter the value for column V20: 67.8
# Enter the value for column V21: 56.7
# Enter the value for column V22: 89.76
# Enter the value for column V23: 4.3
# Enter the value for column V24: 5.6
# Enter the value for column V25: 7.5
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import pandas as pd
dp=pd.read_csv('./dataset/creditcard.csv')
dp.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
plt.hist(['Amount'],color="red",bins=4)
plt.show()

# %%
plt.scatter(['CHART'],['LEVEL'],color="red")
plt.show()

# %%
plt.scatter(['IN_BYTES'],['OUT_BYTES'],color="blue")
plt.title("Scatter Plot")
plt.xlabel("IN_BYTES")
plt.ylabel("OUT_BYTES")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(['Amount'],bins=10)
plt.show()
